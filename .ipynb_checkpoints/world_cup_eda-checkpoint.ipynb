# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %% [markdown]
# # Exploring FIFA World Cup Data
#
# There are 3 dataset provides specific information about FIFA world cup: matches, players, and cups. The primary purpose of this notebook is practice manipulating tabular data in a pandas dataframe.

# %%
matches = pd.read_csv('./data/WorldCupMatches.csv')
players = pd.read_csv('./data/WorldCupPlayers.csv')
cups = pd.read_csv('./data/WorldCups.csv')

# %% [markdown]
# # What does the data look like?
#
# Exploring the first 5 lines of the matches, players, and cups dataframes.

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
players.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
cups.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %% [markdown]
# # Cleaning Dataframes

# %%
print ("number of matches: ", len(matches))
print ("number of players: ",len(players))
print ("number of cups: ", len(cups))
# Out:
# number of matches:  4572
# number of players:  37784
# number of cups:  20

# %%
# well this is weird. 3720 is null out of the matches 4572 records
matches.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
len(matches) - 3720
# Out:
# 852

# %%
# checking what the problem is. It appears scrapped null records
# were added from index 853 onwards
matches = matches[:852]

# %%
# removing all of the null records in the matches dataframe.
matches = matches[:852]

# %%
matches.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %% [markdown]
# # How many World Cup games has a country won?

# %%
def who_won_the_match(row):
    """
        Overview: This function is responsible for determining who won a particular match.
        This is done through simple less than and greater than comparisons between home and 
        away team goals. If the goals are equal then we assign "tie".
        
        Input:
            - row: a row from the pandas dataframe.
        
        Output:
            - the initials of the team that won: home team initials, away team initials, or tie
    """
    
    if row['Home Team Goals'] > row['Away Team Goals']:
        return row['Home Team Initials']
    elif row['Home Team Goals'] < row['Away Team Goals']:
        return row['Away Team Initials']
    else:
        return "tie"

# %%
matches['match_winner'] = matches.apply(who_won_the_match, axis=1)

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions     ...       Half-time Home Goals  Half-time Away Goals  \
# 0                    ...                        3.0                   0.0
# ...

# %%
# counting how matches each country won and were grabbing the top ten
winning_records = matches.groupby(['match_winner']).size().sort_values(ascending=False)
top_ten = winning_records[1:11]

# %%
# Lets plot the top ten. WINNER IS BRAZIL!
top_ten.plot(kind="bar")

# %% [markdown]
# # Plotting Brazil's the number of wins per World Cup
#
# Here we explored the number of wins has brazil per world cup. With the aim to identity which world cups brazil has won so far.

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions     ...       Half-time Home Goals  Half-time Away Goals  \
# 0                    ...                        3.0                   0.0
# ...

# %%
brazil = matches[matches["match_winner"] == "BRA"]

# %%
brazil.head()
# Out:
#       Year              Datetime                  Stage  \
# 11  1930.0  20 Jul 1930 - 13:00                 Group 2
# 40  1938.0  05 Jun 1938 - 17:30             First round
# 48  1938.0  14 Jun 1938 - 18:00          Quarter-finals
# 51  1938.0  19 Jun 1938 - 17:00   Match for third place
# 53  1950.0  24 Jun 1950 - 15:00                 Group 1
#
#                                       Stadium             City Home Team Name  \
# 11                         Estadio Centenario      Montevideo          Brazil
# 40                         Stade de la Meinau      Strasbourg          Brazil
# 48                      Stade du Parc Lescure        Bordeaux          Brazil
# 51                      Stade du Parc Lescure        Bordeaux          Brazil
# 53  Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro          Brazil
#
#     Home Team Goals  Away Team Goals  Away Team Name  \
# 11              4.0              0.0         Bolivia
# ...

# %%
brazilWinsbyYear = brazil.groupby(("Year")).size()

# %%
# it looks like if you win at least 5 games or more you may win the world cup
brazilWinsbyYear.plot(kind="bar")

# %%
cups.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
# what world cups did brazil win?
brazilWins = cups[cups['Winner'] == "Brazil"]

# %%
# looks like the hypothesis were right. Brazil won the world cup in 1958, 1962, 1970, 1994, 2002. All years were they 
# won 5 or more games.
brazilWins.head()
# Out:
#     Year      Country  Winner      Runners-Up       Third          Fourth  \
# 5   1958       Sweden  Brazil          Sweden      France      Germany FR
# 6   1962        Chile  Brazil  Czechoslovakia       Chile      Yugoslavia
# 8   1970       Mexico  Brazil           Italy  Germany FR         Uruguay
# 14  1994          USA  Brazil           Italy      Sweden        Bulgaria
# 16  2002  Korea/Japan  Brazil         Germany      Turkey  Korea Republic
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 5           126              16             35    819.810
# 6            89              16             32    893.172
# 8            95              16             32  1.603.975
# 14          141              24             52  3.587.538
# 16          161              32             64  2.705.197
